# %%
"""
Created on Fri May  2 11:57:23 2020

@author: Shivanshu Agnihotri 

Use jupyter for .ipynb files
"""

#basic graph plotting using matplotlib  


from matplotlib import pyplot as plt

plt.plot([1,2,3],[4,5,1]) 



plt.title("Graph")
plt.ylabel("Y-Axis")
plt.xlabel("X-Axis")

plt.show()

x=[7,8,9]
y=[11,2,16]

xx=[2,9,10]
yy=[19,23,19]


plt.plot(x,y,'g',label='line one')
plt.plot(xx,yy,label='line two')

plt.show()
