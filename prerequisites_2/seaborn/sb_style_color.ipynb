# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
t = sns.load_dataset('tips')
t.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x='sex',data=tips)

# %%
sns.set_style('white') #sets background white
sns.countplot(x='sex',data=t)

# %%
sns.set_style('ticks') #other styples darkgrid , whitegrid 
sns.countplot(x='sex',data=t,palette='deep')

# %%
sns.countplot(x='sex',data=t)
sns.despine() #spine removed

# %%
sns.countplot(x='sex',data=t)
sns.despine(left=True) #spine removed from left

# %%
plt.figure(figsize=(6,4)) #figuresize
sns.countplot(x='sex',data=t)

# %%
sns.lmplot(x='total_bill',y='tip',height=2,aspect=4,data=t) #grid plotting

# %%
sns.set_context('poster',font_scale=2) #context setting
sns.countplot(x='sex',data=t)
